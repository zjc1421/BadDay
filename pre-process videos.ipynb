# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

FOLDERNAME = 'cse493g1/project'
PROJECT_PATH = f'/content/drive/MyDrive/{FOLDERNAME}'
# %cd $PROJECT_PATH
# %cd VLAD/
# !pip install -r requirements.txt
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1OR_G1KW--WU6I4RMVItYt5BhiTf3RMiG/cse493g1/project
# /content/drive/.shortcut-targets-by-id/1OR_G1KW--WU6I4RMVItYt5BhiTf3RMiG/cse493g1/project/VLAD
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 1)) (2.5.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 2)) (1.26.4)
# Collecting pytorchvideo (from -r requirements.txt (line 3))
#   Downloading pytorchvideo-0.1.5.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 4)) (4.46.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 1)) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 1)) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 1)) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->-r requirements.txt (line 1)) (1.3.0)
# Collecting fvcore (from pytorchvideo->-r requirements.txt (line 3))
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting av (from pytorchvideo->-r requirements.txt (line 3))
#   Downloading av-14.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.5 kB)
# Collecting parameterized (from pytorchvideo->-r requirements.txt (line 3))
#   Downloading parameterized-0.9.0-py2.py3-none-any.whl.metadata (18 kB)
# Collecting iopath (from pytorchvideo->-r requirements.txt (line 3))
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 4)) (0.26.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 4)) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 4)) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 4)) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 4)) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 4)) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 4)) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 4)) (4.66.6)
# Collecting yacs>=0.1.6 (from fvcore->pytorchvideo->-r requirements.txt (line 3))
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorchvideo->-r requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorchvideo->-r requirements.txt (line 3)) (11.0.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorchvideo->-r requirements.txt (line 3)) (0.9.0)
# Collecting portalocker (from iopath->pytorchvideo->-r requirements.txt (line 3))
#   Downloading portalocker-3.0.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->-r requirements.txt (line 4)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->-r requirements.txt (line 4)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->-r requirements.txt (line 4)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->-r requirements.txt (line 4)) (2024.8.30)
# Downloading av-14.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.0/33.0 MB 35.6 MB/s eta 0:00:00
# Downloading parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading portalocker-3.0.0-py3-none-any.whl (19 kB)
# Building wheels for collected packages: pytorchvideo, fvcore, iopath
#   Building wheel for pytorchvideo (setup.py) ... done
#   Created wheel for pytorchvideo: filename=pytorchvideo-0.1.5-py3-none-any.whl size=188685 sha256=2292f35077fb0f6671efc851874cf93fd850f3c669e862a0c7ee125b79a37e68
#   Stored in directory: /root/.cache/pip/wheels/ff/4e/81/0f72a543be9ed7eb737c95bfc5da4025e73226b44368074ece
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61396 sha256=6262674ff53c11a5a0627ed0b12d76bf793382933031a2760bad87089e7f8fae
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31528 sha256=b057ff2af97d4f8c49c4121410f2c790992eb932a5c2bee59c30f99346050ed7
#   Stored in directory: /root/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
# Successfully built pytorchvideo fvcore iopath
# Installing collected packages: yacs, portalocker, parameterized, av, iopath, fvcore, pytorchvideo
# Successfully installed av-14.0.0 fvcore-0.1.5.post20221221 iopath-0.1.10 parameterized-0.9.0 portalocker-3.0.0 pytorchvideo-0.1.5 yacs-0.1.8

# %%
import os
import cv2
import numpy as np
import requests

# %%
def preprocess_video_to_npy(video_folder, output_folder, target_frames=32):
    os.makedirs(output_folder, exist_ok=True)

    # Supported video formats
    supported_formats = ('.mp4', '.avi')

    for video_name in os.listdir(video_folder):
        if not video_name.endswith(supported_formats):
            continue

        video_path = os.path.join(video_folder, video_name)
        video_output_path = os.path.join(output_folder, os.path.splitext(video_name)[0] + ".npy")

        cap = cv2.VideoCapture(video_path)
        frames = []

        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break
            frames.append(frame)

        cap.release()
        frames = np.array(frames)  # Shape: (num_frames, height, width, channels)

        num_frames = frames.shape[0]
        if num_frames > target_frames:
            # uniformly sample result frame
            indices = np.linspace(0, num_frames - 1, target_frames, dtype=np.int32)
            frames = frames[indices]
        elif num_frames < target_frames:
            # Pad with black frames
            padding_frames = target_frames - num_frames
            pad = np.zeros((padding_frames, *frames.shape[1:]), dtype=frames.dtype)
            frames = np.concatenate((frames, pad), axis=0)

        # Save as .npy file
        np.save(video_output_path, frames)
        print(f"Saved preprocessed video to {video_output_path}")

# %%
video_folder_Kinetics400 = os.path.join(PROJECT_PATH, "test_videos")
output_folder_Kinetics400 = os.path.join(PROJECT_PATH, "npy_Kinetics400_test")
preprocess_video_to_npy(video_folder_Kinetics400, output_folder_Kinetics400, target_frames=16)
# Out:
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400_test/yimS7fmRQU8.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400_test/yivjJkYiCLA.npy

# %%
video_folder_Kinetics400 = os.path.join(PROJECT_PATH, "Kinetics400-subset")
output_folder_Kinetics400 = os.path.join(PROJECT_PATH, "npy_Kinetics400")

# Preprocess videos
preprocess_video_to_npy(video_folder_Kinetics400, output_folder_Kinetics400)
# Out:
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yjFF7sgHE-A.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/ym2ehgmrqlg.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yimS7fmRQU8.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/ykMqPdIjfxY.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/ykxPuwaOheM.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/ykC62Wi0BFY.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/ykfWdDjL5UA.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/ym1Eu_YVj4s.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yj30goMPLIY.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yi_opsuyb8g.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yiIpsWdwxwk.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yhZCJEr4x1w.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yiMGw0v3RJs.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yhg-IlXcVrE.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yivjJkYiCLA.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yj9OSripN-w.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/ygLKayPwRZA.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/ygP1za_tmx4.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yzSRyYZfvBY.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/ysYxpwOvAzk.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yyBD8B9mShY.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yy9FJMvk_Io.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/ytnsBbsAZV4.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/ytrcR7G8gYQ.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/ytPsj2yOD54.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yxG9LiGMtRU.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/ytGdUDHd4W8.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yykLATuO2pk.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/ysX2iraKsMQ.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/ysIr-YTnCN8.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/ytkKTAP2qPM.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yzN1L8WbsZY.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yziITbgU96M.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yszYp04CCwE.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yxEGKC4YHes.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yu-0Iuz6nF0.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yuIdHtakhRU.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yzdUyn3sHSs.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yymr4YWVFe4.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/yst56ERztUk.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/ytDQqVNcqrw.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z3T07IFhvcY.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z1W6qW2fZGI.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z3Vo79DW7dk.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z6oFh4gBEik.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z4oDHNJNyes.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z2lDdH9UohI.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z6NziPRbdNU.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z4vrNqfF4IE.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z2d9Srt3QB0.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z3G8taVAwOI.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z5jLp8ruSXU.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z2jhS6BOSRs.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z3wWiiK3xuE.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z3osi5OYCtw.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z0UAPZBXmZA.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z5BZhVGR7T0.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z-6l_dkR3vE.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z4o6612UdTo.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z1-U0uYFY3Q.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z2IcCIRBrd8.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z2c0oW2kVNg.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z6gBrkeYWmg.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z5W_W5Rqn4I.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z2jiyBe_GQ4.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/z3s4epg5nVs.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/zE2Xpa8XAtE.npy
# Saved preprocessed video to /content/drive/MyDrive/cse493g1/project/npy_Kinetics400/